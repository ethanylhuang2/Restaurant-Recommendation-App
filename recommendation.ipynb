# %%
import requests
import json
import time
import os
import numpy as np

API_KEY = 'FoF_VUDAtcQlIg24PGQbjXTS1rE16Gtg5OOqEQgpsuaxyxdB1VJqRfYNI0MHoQUl14-KWITKu0FRp1AI3lJpcXFFWYigCMGpv73nkeps2EigzA67DUZbg8UzCwaSZnYx'
HEADERS = {'Authorization': f'Bearer {API_KEY}'}
URL = 'https://api.yelp.com/v3/businesses/search'
DATABASE_FILE = 'restaurants_data.json'

def fetch_yelp_data(location, offset):
    params = {
        'term': 'restaurants',
        'location': location,
        'limit': 50,
        'offset': offset
    }
    response = requests.get(URL, headers=HEADERS, params=params)
    return response.json()

def write_to_file(data):

    if os.path.exists(DATABASE_FILE):
        with open(DATABASE_FILE, 'r') as file:
            file_data = json.load(file)
            existing_business_ids = {business['id'] for business in file_data['businesses']}
    else:
        file_data = {'businesses': []}
        existing_business_ids = set()

    new_businesses = [business for business in data['businesses'] if business['id'] not in existing_business_ids]

    if new_businesses:
        # Append new businesses to the existing data
        file_data['businesses'].extend(new_businesses)

        # Write updated data back to the file
        with open(DATABASE_FILE, 'w') as file:
            json.dump(file_data, file, indent=4)

locations = [
    "Los Angeles, CA", "San Diego, CA", "San Jose, CA", "San Francisco, CA",
    "Fresno, CA", "Sacramento, CA", "Long Beach, CA", "Oakland, CA",
    "Bakersfield, CA", "Anaheim, CA", "Santa Ana, CA", "Riverside, CA",
    "Stockton, CA", "Chula Vista, CA", "Irvine, CA", "Fremont, CA",
    "San Bernardino, CA", "Modesto, CA", "Oxnard, CA", "Fontana, CA",
    "Moreno Valley, CA", "Huntington Beach, CA", "Glendale, CA",
    "Santa Clarita, CA", "Garden Grove, CA", "Oceanside, CA",
    "Rancho Cucamonga, CA", "Santa Rosa, CA", "Ontario, CA",
    "Elk Grove, CA", "Corona, CA", "Lancaster, CA", "Palmdale, CA",
    "Hayward, CA", "Salinas, CA", "Pomona, CA", "Escondido, CA",
    "Torrance, CA", "Pasadena, CA", "Orange, CA", "Fullerton, CA",
    "Roseville, CA", "Visalia, CA", "Concord, CA", "Thousand Oaks, CA",
    "Simi Valley, CA", "Victorville, CA", "Vallejo, CA", "Berkeley, CA"
]


for location in locations:
    offset = 0

    while True:
        data = fetch_yelp_data(location, offset)
        if not data.get('businesses'):
            print("Not valid data")
            print(data)
            offset += 50
            break

        write_to_file(data)
        offset += 50
        time.sleep(1)

        if offset >= data['total']:
            print("No more data")
            break

    print("Moving to next location")
print("Finished fetching data")

# %%
import json
import requests
import time

API_KEY = 'FoF_VUDAtcQlIg24PGQbjXTS1rE16Gtg5OOqEQgpsuaxyxdB1VJqRfYNI0MHoQUl14-KWITKu0FRp1AI3lJpcXFFWYigCMGpv73nkeps2EigzA67DUZbg8UzCwaSZnYx'
HEADERS = {'Authorization': f'Bearer {API_KEY}'}
DETAILS_URL = 'https://api.yelp.com/v3/businesses/'
IMAGES_FILE = 'image_links.json'
DATABASE_FILE = 'restaurants_data.json'

with open(DATABASE_FILE, 'r') as file:
    data = json.load(file)

with open(IMAGES_FILE, 'r') as file:
    image_links = json.load(file)

existing_ids = {item['id'] for item in image_links}


for buisness in data['businesses']:
    if buisness['image_url']:
        id = buisness['id']
        print(id)
        if id not in existing_ids:
            response = requests.get(DETAILS_URL + id, headers=HEADERS)
            details = response.json()
            print(response.json())
            if "image_url" in details:
                image_links.append({
                    "id" : id,
                    "name" : buisness['name'],
                    "image_url" : details["image_url"]
                })
                existing_ids.add(id)
            else:
                print(f"No image for {buisness['name']}")
        else:
            print(f"Already have image for {buisness['name']}")

    time.sleep(0.1)

with open(IMAGES_FILE, 'a') as file:
    json.dump(image_links, file, indent=4)
# Out:
# QueFVMcMlT-6aZFv2M47mg
# Already have image for Bottega
# oK6DQM2ztdNwMAyJqGWZpg
# Already have image for Bettola
# ZSzXw0NgJTyOzcHwKY5eMA
# Already have image for Blind Butcher
# f-m7-hyFzkf0HSEeQ2s-9A
# Already have image for Fog Harbor Fish House
# _hOVIgjVRl_HzvLaa65KJg
# Already have image for The Snug
# lUUQi1b2rV3glIn4t2I1Iw
# Already have image for Horsefeather
# qfRZjzNqO3fRgEGqvGNY-A
# Already have image for Santeria
# XFUQWh46_gISC4jMHlCNmw
# Already have image for Dabao Singapore
# 3o02eHV5vgN2lMY7OkgKHw
# Already have image for Little Aloha
# kLxPWEH56lLeXoNFJyS8HA
# Already have image for Fermentation Lab
# HHtpR0RslupSQ99GIIwW5A
# Already have image for Marufuku Ramen
# qcTW3btfGVVnQQ3DG3KwdQ
# Already have image for La Sarrasine
# x2djtavZIsv84ZKnz_vRMA
# Already have image for Beretta Divisadero
# U7xNnqW_rXeo7G58JXr4uA
# Already have image for little shucker
# 2E9O-p-lp587aOMnpLepkQ
# Already have image for JIJIME
# FbLIxBVJAxAZPgKJsAuVSA
# Already have image for Tacos El Tucan - San Francisco
# E_W8aGdYm8hnfy1WuGJcVQ
# Already have image for Pinsa Rossa
# HEzzsy7TJXbz8ckn6g2Jdg
# Already have image for Minnie Bells Soul Movement
# s2R3RUJ09eBFvHVIUS4Shg
# Already have image for Kothai Republic
# kOYj2sGMZnyC1lU-_Uw5fA
# Already have image for Cha Cha Cha
# MaaySW1ejpwQCkr9jn1glA
# Already have image for The Tailor's Son
# ttarnopezxmp2ROB1N2PaA
# Already have image for Nopa
# lz7EgaxedlmKRq9hrFkulA
# Already have image for Khao Tiew
# 1FSl22I7HM6rJyKC9l4yIw
# Already have image for Memento SF
# d5752S_RDb26HxoL6O06eQ
# Already have image for Beit Rima
# tZmiZw49SNRVzF6h1Jfx9g
# Already have image for Ben Thai Cafe
# sfqkkqFmmYGOT0PCbbD9ZQ
# Already have image for Pearl
# o4V-TCAgB6_WQfRGvpBM3Q
# Already have image for The Rustic
# 8dUaybEPHsZMgr1iKgqgMQ
# Already have image for Sotto Mare
# RjPKqHk_FiegJVCekbJ4Mw
# Already have image for 606
# x0CorPaOx_2o-Pkwqy-B3Q
# Already have image for Dumpling Story
# J7_-faNq_Ag9qTOlDn81Pw
# Already have image for Slice House by Tony Gemignani
# Ncdi3ruiudpD06_a6s3xqg
# Already have image for Kogi Gogi BBQ
# GyGNciKqyJ3ELHmw9jMeRA
# Already have image for Souvla
# 0tiSST3GCwTa7eqY6yTlHQ
# Already have image for Tastebuds
# UNmJz8U03hjA5I5DB87BBw
# Already have image for Berliner Berliner
# z1vcsPf9EgBofmg5luEkAQ
# Already have image for Fiorella -Clement
# buA-RRRH93ncta-qlo0tqg
# Already have image for Karahi House
# 4V6NCkh50A7ihed8g6OH_g
# Already have image for Square Pie Guys
# LkKjTQOZECM8vqaD3kSDoA
# Already have image for RT Rotisserie
# Ucm6J4WfF3ipGwpTuxH05g
# Already have image for Saru Handroll Bar
# haFRimHPOq90EiTplF4S8A
# Already have image for Cafe Europa
# TJZLyTUqtwgsXS439U641w
# Already have image for New Burma
# hT72td0gX3rtgm0iGVlQ_w
# Already have image for 7 Adams
# NwqdohySKrDnK0RsAde9UA
# Already have image for Hot Sauce and Panko
# Ef6W1bNPINIc1sELv-FAnQ
# Already have image for Foliage
# rnwZTR_YJd0vQdEMuXTS5A
# Already have image for Halal Dastarkhan
# IdqBJvRIA0YPwLZaoUNM0w
# Already have image for Waraku
# 4YQg81cDjn2Ei7NYvRHXpA
# Already have image for Chouquet's
# DgfhciOcB9X7SXFFQR7t9w
# Already have image for Blue Barn-Polk
# kOYGw8K1be13ADeBNPsnzw
# Already have image for Parton The Interruption
# WcSZ4K4ADBAxeWyW-FRfrw
# Already have image for Mediterranean Aroma
# ksp8GZtuNLzS9w-AgLjyrw
# Already have image for Emmita's Cafe
# Hq5ZJEcEViFYMy3vfN8WTA
# Already have image for Burma Love - Downtown
# Gl7d3QlfXyGbr7w2241Spg
# Already have image for Bundoks Burgers
# KarMlfJURqPo70kQZ4LzFg
# Already have image for Tarragon Cafe
# Qbr2JG96K6d31NqqAUxf9g
# Already have image for La Mar Cocina Peruana
# 5sBKlZlsTFZqNnVAPjzUoQ
# {'id': '5sBKlZlsTFZqNnVAPjzUoQ', 'alias': 'go-go-7-san-francisco-4', 'name': 'Go Go 7', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uhk9Oc8ZgKjGxHMVZdrhig/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/go-go-7-san-francisco-4?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14153334344', 'display_phone': '(415) 333-4344', 'review_count': 476, 'categories': [{'alias': 'korean', 'title': 'Korean'}], 'rating': 4.5, 'location': {'address1': '1300 Ocean Ave', 'address2': '', 'address3': None, 'city': 'San Francisco', 'zip_code': '94112', 'country': 'US', 'state': 'CA', 'display_address': ['1300 Ocean Ave', 'San Francisco, CA 94112'], 'cross_streets': 'Plymouth Ave & Granada Ave'}, 'coordinates': {'latitude': 37.724133, 'longitude': -122.4566716}, 'photos': [], 'price': '$$', 'hours': [{'open': [{'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2}, {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3}, {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 4}, {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5}, {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}], 'hours_type': 'REGULAR', 'is_open_now': False}], 'transactions': ['delivery']}
# l7FgB0X6a-eM0U_M9pvMUA
# {'id': 'l7FgB0X6a-eM0U_M9pvMUA', 'alias': 'noriega-cafe-san-francisco', 'name': 'Noriega Cafe', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ko0nuQD7Wxg0ec6m1rLJDw/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/noriega-cafe-san-francisco?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14157026218', 'display_phone': '(415) 702-6218', 'review_count': 122, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 3.9, 'location': {'address1': '1245 Noriega St', 'address2': None, 'address3': '', 'city': 'San Francisco', 'zip_code': '94122', 'country': 'US', 'state': 'CA', 'display_address': ['1245 Noriega St', 'San Francisco, CA 94122'], 'cross_streets': '19th Ave & 20th Ave'}, 'coordinates': {'latitude': 37.75406, 'longitude': -122.47728}, 'photos': [], 'price': '$$', 'hours': [{'open': [{'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 0}, {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 1}, {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 3}, {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4}, {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5}, {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 6}], 'hours_type': 'REGULAR', 'is_open_now': True}], 'transactions': ['pickup', 'delivery'], 'messaging': {'url': 'https://www.yelp.com/raq/l7FgB0X6a-eM0U_M9pvMUA?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ#popup%3Araq', 'use_case_text': 'Message the Business'}}
# T6krutcCsZ317NS_EGbUZQ
# {'id': 'T6krutcCsZ317NS_EGbUZQ', 'alias': 'four-kings-san-francisco', 'name': 'Four Kings', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZpsjSKVsmxxxWAWGOQXISA/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/four-kings-san-francisco?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '', 'display_phone': '', 'review_count': 85, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}], 'rating': 4.5, 'location': {'address1': '710 Commercial St', 'address2': '', 'address3': None, 'city': 'San Francisco', 'zip_code': '94108', 'country': 'US', 'state': 'CA', 'display_address': ['710 Commercial St', 'San Francisco, CA 94108'], 'cross_streets': 'Kearny St & Grant Ave'}, 'coordinates': {'latitude': 37.79409, 'longitude': -122.40506}, 'photos': [], 'hours': [{'open': [{'is_overnight': False, 'start': '1800', 'end': '2300', 'day': 0}, {'is_overnight': False, 'start': '1800', 'end': '2300', 'day': 3}, {'is_overnight': False, 'start': '1800', 'end': '2300', 'day': 4}, {'is_overnight': False, 'start': '1800', 'end': '2300', 'day': 5}, {'is_overnight': False, 'start': '1800', 'end': '2300', 'day': 6}], 'hours_type': 'REGULAR', 'is_open_now': False}], 'attributes': {'menu_url': 'https://www.itsfourkings.com/menu'}, 'transactions': [], 'messaging': {'url': 'https://www.yelp.com/raq/T6krutcCsZ317NS_EGbUZQ?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ#popup%3Araq', 'use_case_text': 'Message the Business'}}
# 5D--FJXQHdC3kZWYm2GREg
# {'id': '5D--FJXQHdC3kZWYm2GREg', 'alias': 'barcha-san-francisco', 'name': 'Barcha', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0eAEaTTCEaSvAzcqAx9uEg/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/barcha-san-francisco?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14157570781', 'display_phone': '(415) 757-0781', 'review_count': 803, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.1, 'location': {'address1': '28 Fremont St', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94105', 'country': 'US', 'state': 'CA', 'display_address': ['28 Fremont St', 'San Francisco, CA 94105'], 'cross_streets': 'Front St & Mission St'}, 'coordinates': {'latitude': 37.7909966558218, 'longitude': -122.397482693195}, 'photos': [], 'price': '$$$', 'hours': [{'open': [{'is_overnight': False, 'start': '1130', 'end': '1400', 'day': 0}, {'is_overnight': False, 'start': '1530', 'end': '2100', 'day': 0}, {'is_overnight': False, 'start': '1130', 'end': '1400', 'day': 1}, {'is_overnight': False, 'start': '1530', 'end': '2100', 'day': 1}, {'is_overnight': False, 'start': '1130', 'end': '1400', 'day': 2}, {'is_overnight': False, 'start': '1530', 'end': '2100', 'day': 2}, {'is_overnight': False, 'start': '1130', 'end': '1400', 'day': 3}, {'is_overnight': False, 'start': '1530', 'end': '2100', 'day': 3}, {'is_overnight': False, 'start': '1130', 'end': '1400', 'day': 4}, {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 4}, {'is_overnight': False, 'start': '1730', 'end': '2100', 'day': 5}], 'hours_type': 'REGULAR', 'is_open_now': True}], 'attributes': {'menu_url': 'https://barcha-sf.com/new-folder-1', 'waitlist_reservation': True}, 'transactions': ['pickup', 'delivery'], 'messaging': {'url': 'https://www.yelp.com/raq/5D--FJXQHdC3kZWYm2GREg?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ#popup%3Araq', 'use_case_text': 'Message the Business'}, 'special_hours': [{'date': '2024-09-02', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}, {'date': '2024-11-11', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}, {'date': '2024-11-29', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}, {'date': '2024-12-24', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}, {'date': '2024-12-25', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}, {'date': '2025-01-01', 'is_closed': True, 'start': None, 'end': None, 'is_overnight': None}]}
# wCf2GGyEOkaSFE0xCYpgOA
# {'id': 'wCf2GGyEOkaSFE0xCYpgOA', 'alias': 'hai-ky-noodles-san-francisco', 'name': 'Hai Ky Noodles', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U3T7PQZfq10a7ZkiGdsN0w/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/hai-ky-noodles-san-francisco?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14157712577', 'display_phone': '(415) 771-2577', 'review_count': 1221, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.3, 'location': {'address1': '707 Ellis St', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94109', 'country': 'US', 'state': 'CA', 'display_address': ['707 Ellis St', 'San Francisco, CA 94109'], 'cross_streets': 'Larkin St & Polk St'}, 'coordinates': {'latitude': 37.7840538024902, 'longitude': -122.417953491211}, 'photos': [], 'price': '$$', 'hours': [{'open': [{'is_overnight': False, 'start': '0900', 'end': '1830', 'day': 0}, {'is_overnight': False, 'start': '0900', 'end': '1830', 'day': 3}, {'is_overnight': False, 'start': '0900', 'end': '1830', 'day': 4}, {'is_overnight': False, 'start': '0900', 'end': '1830', 'day': 5}, {'is_overnight': False, 'start': '0900', 'end': '1830', 'day': 6}], 'hours_type': 'REGULAR', 'is_open_now': False}], 'transactions': ['pickup', 'delivery']}
# sec_72MjQnif4OvsqJ2pUA
# {'id': 'sec_72MjQnif4OvsqJ2pUA', 'alias': 'macondray-san-francisco', 'name': 'Macondray', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JqVHBF1JW3daLmyg3t6Ifw/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/macondray-san-francisco?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14158293464', 'display_phone': '(415) 829-3464', 'review_count': 189, 'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'tradamerican', 'title': 'American'}], 'rating': 4.3, 'location': {'address1': '2209 Polk St', 'address2': None, 'address3': '', 'city': 'San Francisco', 'zip_code': '94109', 'country': 'US', 'state': 'CA', 'display_address': ['2209 Polk St', 'San Francisco, CA 94109'], 'cross_streets': 'Vallejo St & Bonita St'}, 'coordinates': {'latitude': 37.797113, 'longitude': -122.422249}, 'photos': [], 'price': '$$', 'hours': [{'open': [{'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 0}, {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 1}, {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 2}, {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 3}, {'is_overnight': True, 'start': '1600', 'end': '0100', 'day': 4}, {'is_overnight': True, 'start': '1400', 'end': '0100', 'day': 5}, {'is_overnight': False, 'start': '1400', 'end': '2130', 'day': 6}], 'hours_type': 'REGULAR', 'is_open_now': False}], 'transactions': ['delivery']}
# d40PbnRah7AWH_dclw1h_Q
# {'id': 'd40PbnRah7AWH_dclw1h_Q', 'alias': 'rintaro-san-francisco-4', 'name': 'Rintaro', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cRISagINMhjga_ekR98I0g/o.jpg', 'is_claimed': True, 'is_closed': False, 'url': 'https://www.yelp.com/biz/rintaro-san-francisco-4?adjust_creative=hwSt6PK9qVrHDQnJdB1hJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=hwSt6PK9qVrHDQnJdB1hJQ', 'phone': '+14155897022', 'display_phone': '(415) 589-7022', 'review_count': 984, 'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}], 'rating': 4.2, 'location': {'address1': '82 14th St', 'address2': '', 'address3': '', 'city': 'San Francisco', 'zip_code': '94103', 'country': 'US', 'state': 'CA', 'display_address': ['82 14th St', 'San Francisco, CA 94103'], 'cross_streets': 'Folsom St & Trainor St'}, 'coordinates': {'latitude': 37.76881, 'longitude': -122.41511}, 'photos': [], 'price': '$$$', 'hours': [{'open': [{'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 0}, {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 1}, {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2}, {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3}, {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4}, {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5}], 'hours_type': 'REGULAR', 'is_open_now': False}], 'attributes': {'menu_url': 'https://www.izakayarintaro.com/#menu'}, 'transactions': ['delivery']}
# hqQoVK0vadOX7_4gN1sh3g
# ...
# LNHBjjH0QRCHqyAYnFuNPw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Feng Ze Yuan 鋒味館
# FIVsOnjPNOF-jmpn3DVc-A
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Unwine'd SF
# hpWcjUQ0dhXRN-2wUWQYCQ
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Cinderella Bakery & Cafe
# NH1tpRk-TypznNFACTTDuw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Sasa Japanese restaurant
# LMs63-rIlbFu9Co45bgHxQ
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Casey's Pizza
# NIIYYMc6GeQW4heDd7v_6w
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for United Dumplings
# fchN6rNVAb1-OqxLMcdrvA
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Ichido
# 2ocTtBOx-1TghQrBxFjORg
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Kababayan
# TyGQGbz1H5ehDZdOId27Ug
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Wabi-Sabi SF At Soma
# IhYCdP5Oe2H-eWzlLPmrFQ
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Lunette
# vLNzJX1ctfP4NNESCFOeGw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Son & Garden
# TF0G4kTPfsnB7yZJHLWJEQ
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Tiny Sushi - Oh Baby
# fUXIfOzui4fEy7mPT_R0dg
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for La Arepa
# Tw_cduegCKez_XfqYDXjng
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Boudin
# wxzx3duu1c0CcomzEOvfOQ
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for The Front Porch
# AQjSsLrOheQ1snPWtYwv3w
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Toyose
# f3ekmqWreEhlrxRWDNBHDw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Dragon Horse
# 2BCWdn_ltDjzHGhVOIAfDA
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Back to Back
# GCZlI_hpsxQlD2wAqGQCuA
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Sister Mother Crone
# RetHDxQ2RoHxGBBrvoR86g
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for orafo
# imHjAJ9uuUK_PNkzT9kCag
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Basa Seafood Express
# RrBURifuO-glm4oM43IFZw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Martha's Restaurent
# nAmR7DYJAmSWRiDfix7dmw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Papaya Island
# El1fNeBVBglXlZtFuq4SWA
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Saffron Grill
# ULfV_A8-YxuBq2YcapJUmw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Yongzi Ji Restaurant
# r0nneJppujX4WuUffv4dLA
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Hon's Wun-Tun House
# _BDoTBI2YlyUaWFOXBEF8Q
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Sababa
# Ldq4XfNsXM-ciulyDUlMmw
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Sweet Lime Thai Cuisine
# 1vx9yBm6h1IOvwqtX2Acog
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}
# No image for Seven Square Taproom
# ri7UUYmx21AgSpRsf4-9QA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      23 print(id)
#      24 if id not in existing_ids:
# ---> 25     response = requests.get(DETAILS_URL + id, headers=HEADERS)
#      26     details = response.json()
#      27     print(response.json())
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/food_recommendation/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
response = requests.get(DETAILS_URL + id, headers=HEADERS)
print(response.json())
# Out:
# {'error': {'code': 'ACCESS_LIMIT_REACHED', 'description': "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}

# %%
with open(IMAGES_FILE, 'w') as file:
    json.dump(image_links, file, indent=4)

# %%
import pandas as pd
import json
import os

DATABASE_FILE = 'restaurants_data.json'

def parse_yelp_data(json_data):
    restaurants = []
    for business in json_data['businesses']:
        if 'price' in business  and business['location']['address1']:
            restaurant = {
                'id' : business['id'],
                'name': business['name'],
                'cuisine': ', '.join([category['title'] for category in business['categories']]),
                'city': business['location']['city'],
                'address': business['location']['address1'],
                'price_range': business.get('price', 'N/A'),
                'average_rating': business['rating'],
                'review_count': business['review_count']
            }
            restaurants.append(restaurant)
    return restaurants


def load_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)



json_data = load_json_file(DATABASE_FILE)
parsed_data = parse_yelp_data(json_data)


restaurants_df = pd.DataFrame(parsed_data)
print(restaurants_df.shape)
restaurants_df.head()
# Out:
# (9356, 8)
#                        id                   name  \
# 0  QueFVMcMlT-6aZFv2M47mg                Bottega
# 1  ZSzXw0NgJTyOzcHwKY5eMA          Blind Butcher
# 2  f-m7-hyFzkf0HSEeQ2s-9A  Fog Harbor Fish House
# 3  _hOVIgjVRl_HzvLaa65KJg               The Snug
# 4  lUUQi1b2rV3glIn4t2I1Iw           Horsefeather
#
#                              cuisine           city            address  \
# 0        Italian, Pasta Shops, Pizza  San Francisco   1132 Valencia St
# 1            New American, Wine Bars  San Francisco       4058 18th St
# 2  Seafood, Wine Bars, Cocktail Bars  San Francisco            39 Pier
# 3        Cocktail Bars, New American  San Francisco   2301 Fillmore St
# 4        Cocktail Bars, New American  San Francisco  528 Divisadero St
#
#   price_range  average_rating  review_count
# 0          $$             4.3          1119
# 1          $$             4.1           376
# 2          $$             4.4         10499
# 3          $$             4.0           439
# 4          $$             4.0           606

# %%
duplicate_rows = restaurants_df[restaurants_df.duplicated()]
duplicate_rows.head()
# Out:
# Empty DataFrame
# Columns: [id, name, cuisine, city, address, price_range, average_rating, review_count]
# Index: []

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

restaurants_df['combined_features'] = (
    restaurants_df['cuisine'] + ' ' +
    restaurants_df['price_range'] + ' ' +
    restaurants_df['city'] + ' ' +
    restaurants_df['average_rating'].astype(str) + ' ' +
    restaurants_df['review_count'].astype(str)
)

vectorizer = TfidfVectorizer()
feature_matrix = vectorizer.fit_transform(restaurants_df['combined_features'])
similarity_matrix = cosine_similarity(feature_matrix)

# %%
def get_recommendations(restaurant_name, df, similarity_matrix, top_n=10):
    try:
        # Find the index of the restaurant
        idx = df[df['name'].str.contains(restaurant_name, case=False, na=False)].index[0]

        # Get the similarity scores for this restaurant
        sim_scores = list(enumerate(similarity_matrix[idx]))

        # Sort the restaurants based on similarity scores
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

        # Get the scores of the top_n most similar restaurants
        sim_scores = sim_scores[1:top_n+1]

        # Get the restaurant indices
        restaurant_indices = [i[0] for i in sim_scores]

        # Return the top_n most similar restaurants
        return df.iloc[restaurant_indices][['name', 'cuisine', 'city', 'average_rating', 'price_range']]
    except IndexError:
        return pd.DataFrame(columns=['name', 'cuisine', 'city', 'average_rating', 'price_range'])

# %%
recommendations = get_recommendations('Marufuku Ramen', restaurants_df, similarity_matrix, top_n=5)
recommendations.head()
# Out:
#                       name              cuisine           city  \
# 102        Ushi Taro Ramen                Ramen  San Francisco
# 44    Noodle in a Haystack  Ramen, New American  San Francisco
# 5123          Sun and Moon          Thai, Ramen  San Francisco
# 85      Hinodeya Japantown                Ramen  San Francisco
# 345       Mangrove Kitchen          Thai, Ramen  San Francisco
#
#       average_rating price_range
# 102              4.3          $$
# 44               4.8        $$$$
# 5123             4.2          $$
# 85               4.2          $$
# 345              4.0          $$

# %%
def get_user_pref_vector(user_ratings, df, vectorizer):
    rated_restaurants = df[df['name'].isin(user_ratings.keys())]
    ratings = [user_ratings[name] for name in rated_restaurants['name']]
    rated_features = vectorizer.transform(rated_restaurants['combined_features'])
    weighted_average = sum(r * f for r, f in zip(ratings, rated_features)) / sum(ratings)
    
    return weighted_average

# %%
def get_user_recommendations(user_ratings, df, vectorizer, similarity_matrix, top_n=10):
    user_pref_vector = get_user_pref_vector(user_ratings, df, vectorizer)
    sim_scores = cosine_similarity(user_pref_vector, vectorizer.transform(df['combined_features'])).flatten()
    sim_scores = sorted(enumerate(sim_scores), key=lambda x: x[1], reverse=True)
    rated_restaurant_indices = df[df['name'].isin(user_ratings.keys())].index
    sim_scores = [(i, score) for i, score in sim_scores if i not in rated_restaurant_indices]
    sim_scores = sim_scores[:top_n]
    restaurant_indices = [i[0] for i in sim_scores]
    return df.iloc[restaurant_indices][['name', 'cuisine', 'city', 'average_rating', 'price_range']]

# %%
user_ratings = {
    "Donato & Co" : 1,
    "Masa Ramen Bistro" : 5,
    "Fog Harbor Fish House": 1,
    "The Snug" : 1,
    "Horsefeather" : 1,
    "Santeria" : 1
}

recommendations = get_user_recommendations(user_ratings, restaurants_df, vectorizer, similarity_matrix, top_n=5)
recommendations.head()
# Out:
#                     name                              cuisine           city  \
# 619   Hinodeya Ramen Bar                Ramen, Japanese Curry  San Francisco
# 1409  Muracci's Berkeley                       Japanese Curry       Berkeley
# 198         Nippon Curry                       Japanese Curry  San Francisco
# 1369     Dela Curo Curry  Sandwiches, Japanese Curry, Burgers       Berkeley
# 1172    Champion's Curry    Japanese Curry, Salad, Sandwiches       Berkeley
#
#       average_rating price_range
# 619              4.3          $$
# 1409             3.5          $$
# 198              4.5          $$
# 1369             4.2          $$
# 1172             3.9          $$
